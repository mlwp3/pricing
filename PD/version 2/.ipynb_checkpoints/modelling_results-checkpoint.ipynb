# %% [markdown]
# # Combine frequency and severity projections

# %%
import pandas as pd
import numpy as np

import data_utils as du

# %% [markdown]
# ## load the predictor files

# %%
freq_train_file = r'freq_train.pkl'
freq_train = pd.read_pickle(freq_train_file)
    
sev_train_file = r'sev_train.pkl'
sev_train = pd.read_pickle(sev_train_file)

freq_test_file = r'freq_test.pkl'
freq_test = pd.read_pickle(freq_train_file)
    
sev_test_file = r'sev_test.pkl'
sev_test = pd.read_pickle(sev_train_file)

# %%
data_train = freq_train.join(sev_train['severity_predicted'])
data = freq_test.join(sev_test['severity_predicted'])
data.head()
# Out:
#           ClaimNb  Exposure Area  VehPower  BonusMalus VehBrand   VehGas  \
# RecordID
# 2               1      0.09    B         7          50      B12   Diesel
# 4               1      0.72    C         9          50      B12  Regular
# 7               0      0.67    B         7          50      B12   Diesel
# 9               0      1.00    C         4          50       B6  Regular
# 10              0      0.96    E         6          50      B12  Regular
#
#           Density Region  ClaimAmount DrivAgeBand    DensityBand VehAgeBand  \
# RecordID
# 2              76    R72          0.0     (45,55]       (50,100]          0
# 4             366    R82          0.0     (55,65]      (200,400]          0
# 7              54    R22          0.0     (45,55]       (50,100]          0
# 9             141    R82          0.0     (35,45]      (100,200]         12
# 10           3003    R31          0.0     (35,45]  (2e+03,5e+03]          3
#
# ...

# %%
# adjust to predict claim numbers

#test data
data_train['ClaimNb_predicted'] = (data_train['freq_predicted']*data_train['Exposure'])
data_train['ClaimNb_predicted_round'] = data_train['ClaimNb_predicted'].round(0)

#train data
data['ClaimNb_predicted'] = data['freq_predicted']*data['Exposure']
data['ClaimNb_predicted_round'] = data['ClaimNb_predicted'].round(0)

# adjust severity projection
data_train['ClaimAmount_predicted'] = data_train['ClaimNb_predicted_round']*data_train['severity_predicted']
data['ClaimAmount_predicted'] = data['ClaimNb_predicted_round']*data['severity_predicted']


data[:5]
# Out:
#           ClaimNb  Exposure Area  VehPower  BonusMalus VehBrand   VehGas  \
# RecordID
# 2               1      0.09    B         7          50      B12   Diesel
# 4               1      0.72    C         9          50      B12  Regular
# 7               0      0.67    B         7          50      B12   Diesel
# 9               0      1.00    C         4          50       B6  Regular
# 10              0      0.96    E         6          50      B12  Regular
#
#           Density Region  ClaimAmount DrivAgeBand    DensityBand VehAgeBand  \
# RecordID
# 2              76    R72          0.0     (45,55]       (50,100]          0
# 4             366    R82          0.0     (55,65]      (200,400]          0
# 7              54    R22          0.0     (45,55]       (50,100]          0
# 9             141    R82          0.0     (35,45]      (100,200]         12
# 10           3003    R31          0.0     (35,45]  (2e+03,5e+03]          3
#
# ...

# %%
data_train[['ClaimAmount','ClaimAmount_predicted', 'ClaimNb','ClaimNb_predicted_round']].describe()
# Out:
#          ClaimAmount  ClaimAmount_predicted        ClaimNb  \
# count  394400.000000          394379.000000  394400.000000
# mean       87.941645              16.601018       0.065360
# std      2131.856196             198.141068       0.288774
# min         0.000000               0.000000       0.000000
# 25%         0.000000               0.000000       0.000000
# 50%         0.000000               0.000000       0.000000
# 75%         0.000000               0.000000       0.000000
# max    774411.500000           30652.675641      16.000000
#
#        ClaimNb_predicted_round
# count            394400.000000
# mean                  0.019361
# std                   0.160281
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                  15.000000

# %%
cols_to_drop = ['Density','ClaimAmount','severity','freq_predicted','severity_predicted','BonusMalus','Exposure','ClaimNb_predicted','ClaimAmount_predicted']
#cols_to_drop = ['Density','severity','Claim_xs000k','Claim_xs100k','Claim_xs500k','freq_predicted','severity_predicted','BonusMalus','Exposure','ClaimNb_predicted_round', 'ClaimNb', 'ClaimNb_predicted']

data_to_plot = data.drop(cols_to_drop, axis='columns').copy()
data_to_plot_train = data_train.drop(cols_to_drop, axis='columns').copy()

fig = du.plot_factors(data_to_plot_train, 'ClaimNb', 'ClaimNb_predicted_round')
#fig = du.plot_factors(data_to_plot_train, 'ClaimAmount', 'ClaimAmount_predicted')

fig.show()
# Out:
# ClaimNb
# --target
# Area
# VehPower
# VehBrand
# VehGas
# Region
# DrivAgeBand
# DensityBand
# VehAgeBand
# ClaimNb_predicted_round
# --target
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.
