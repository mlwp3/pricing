# %% [markdown]
# # Severity Projection

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import r2_score,mean_squared_error

from sklearn.datasets import make_classification

import matplotlib.pyplot as plt

import data_cleansing as dc
import data_utils as du

# %% [markdown]
# ## load the data and apply cleaning steps

# %%
data_train_raw, data_test_raw = dc.load_file()

data_test = data_test_raw.copy()
data_train = data_train_raw.copy()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
target_name='severity'

# %% [markdown]
# ## Setup the dataset

# %% [markdown]
# ## Apply lable encoding to the factors

# %%
label_encode_factors = ['Area',
                        'VehPower',
                        'VehBrand',
                        'VehGas',
                        'Region',
                        'DrivAgeBand',
                        'DensityBand',
                        'VehAgeBand',
                        ]
# encode training data and save encoders used
data_train_encoded, encoders = du.preprocess_labelencode(data_train, label_encode_factors)
# apply trained encoders to test set
data_test_encoded = du.preprocess_labelencode_apply(encoders, data_test, label_encode_factors)

# %% [markdown]
# ## Cap the claim values to controll outliers

# %%
#cap large claims
severity_cap = 50e3
data_train_encoded[target_name] = data_train_encoded[target_name].where(data_train_encoded[target_name]<severity_cap, severity_cap)
data_test_encoded[target_name]  = data_test_encoded[target_name].where(data_test_encoded[target_name]<severity_cap, severity_cap)

# %% [markdown]
# ## Remove policies with no claims to train the model (include/exclude zero value claims)

# %%
#data_train_resampled = data_train_encoded.loc[data_train_encoded[target_name]>0]      # this excludes zero claims
data_train_resampled = data_train_encoded.loc[data_train_encoded['ClaimNb']>0].copy() # this includes zero claims
data_test_resampled = data_test_encoded.loc[data_test_encoded['ClaimNb']>0].copy() # this includes zero claims

# %% [markdown]
# # Setup the Random Forest model

# %% [markdown]
# ## Split target from factors

# %%
col_factors = ['Area',
                'VehPower',
                'VehBrand',
                'VehGas',
                'Region',
                'DrivAgeBand',
                'DensityBand',
                'VehAgeBand',
                ]

#sets used to train (resampled sets)
x_train = data_train_resampled[col_factors].copy()
x_train_weights = data_train_resampled['Exposure']
y_train = data_train_resampled[target_name].copy()

#sets used to predict (and evaluate prediction)
x_test = data_test_resampled[col_factors].copy()
y_test = data_test_resampled[target_name].copy()

# %% [markdown]
# ## Build the model and predict

# %%
# %%time
clf_rf = RandomForestRegressor(min_samples_leaf=30, 
                                n_estimators=200,
                                max_depth=10,
                                max_features='auto',
                                criterion='mse',    #mse or mae
                                verbose=True,
                                oob_score=True,
                                n_jobs=3)
#fit values
clf_rf = clf_rf.fit(x_train.values, 
                    y_train.values,
                    sample_weight=x_train_weights)
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=3)]: Done 200 out of 200 | elapsed:    3.6s finished
# Wall time: 4.74 s

# %%
#predict values
y_train_predicted_rf = clf_rf.predict(x_train.values)    
y_test_predicted_rf  = clf_rf.predict(x_test.values)
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=3)]: Done 200 out of 200 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 200 out of 200 | elapsed:    0.0s finished

# %% [markdown]
# ## Merge results back to data set

# %%
target_name_predicted = target_name + '_predicted'

out_train = x_train.copy()
out_test = x_test.copy()

out_train[target_name_predicted] = y_train_predicted_rf
out_train[target_name] = y_train
out_test[target_name_predicted] = y_test_predicted_rf
out_test[target_name] = y_test

# %%
out_test.head()
# Out:
#           Area  VehPower  VehBrand  VehGas  Region  DrivAgeBand  DensityBand  \
# RecordID
# 1            0         1         3       1      15            2            0
# 1            4         1         3       1      20            2            4
# 1            4         0         0       1       0            0            4
# 1            3         5         3       1      20            4            5
# 1            4         4         3       1      20            5            4
#
#           VehAgeBand  severity_predicted  severity
# RecordID
# 1                  0         1491.689833   3986.67
# 1                  0         2041.748880    971.98
# 1                  2         1790.018133   1442.75
# 1                  0         1845.683010    637.41
# 1                 11         2156.052780    384.77

# %% [markdown]
# # Test the results

# %%
# total claim results
train_results_actual = out_train[target_name].sum()
train_results_predict = out_train[target_name_predicted].sum()

test_results_actual = out_test[target_name].sum()
test_results_predict = out_test[target_name_predicted].sum()

# gini results
train_results_gini = du.gini(out_train[target_name].values, out_train[target_name_predicted].values)
test_results_gini =  du.gini(out_test[target_name].values,  out_test[target_name_predicted].values)
# mean squared error
train_results_rmse = np.sqrt(mean_squared_error(out_train[target_name].values, out_train[target_name_predicted].values))
test_results_rmse  = np.sqrt(mean_squared_error(out_test[target_name].values,  out_test[target_name_predicted].values))

print('Total Claims: ',
      'Train Actual {:,.5f}'.format(train_results_actual),
      'Test Actual {:,.5f}'.format(test_results_actual))
print('Total Claims: ', 
      'Train Predic {:,.5f}'.format(train_results_predict),
      'Test Predic {:,.5f}'.format(test_results_predict))

print('Gini Results: ',
      'Train {:,.5f}'.format(train_results_gini),
      'Test {:,.5f}'.format(test_results_gini))
print('RMSE Results: ',
      'Train {:,.5f}'.format(train_results_rmse),
      'Test {:,.5f}'.format(test_results_rmse))

print('Factor Importance:\n', pd.DataFrame(zip(clf_rf.feature_importances_, out_train.columns)).sort_values(0, ascending=False))
# Out:
# Total Claims:  Train Actual 28,574,212.98292 Test Actual 12,041,000.32729
# Total Claims:  Train Predic 27,068,711.25525 Test Predic 11,299,768.76238
# Gini Results:  Train 0.11779 Test 0.00293
# RMSE Results:  Train 3,682.79113 Test 3,760.45440
# Factor Importance:
#            0            1
# 7  0.229680   VehAgeBand
# 4  0.170769       Region
# 1  0.136655     VehPower
# 5  0.127921  DrivAgeBand
# 2  0.125708     VehBrand
# 6  0.087606  DensityBand
# 0  0.077382         Area
# 3  0.044278       VehGas

# %% [markdown]
# ### Output the results

# %%
out_train.to_csv('sev_train.csv')
out_test.to_csv('sev_test.csv')

print(len(out_train), len(out_test))
# Out:
# 16874 7035

# %% [markdown]
# # Review the Results in Charts

# %% [markdown]
# ## Plot of distribution of results

# %%
#%% plot distribution charts
#x_train_to_predict[[target_name, target_name_predicted]].plot(kind='kde', figsize=(20,10))
#x_test[[target_name, target_name_predicted]].plot(kind='kde', figsize=(20,10))

# %% [markdown]
# ## Plot of mean claim numbers split by factor level

# %% [markdown]
# ### Plot fit of data

# %%
fig = du.plot_factors(out_test, target_name, target_name_predicted, out_train)
fig.show()
# Out:
# Area
# VehPower
# VehBrand
# VehGas
# Region
# DrivAgeBand
# DensityBand
# VehAgeBand
# severity_predicted
# --target
# severity
# --target
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
